# %% [markdown]
# <a href="https://colab.research.google.com/github/mvaabox/Portofolio/blob/main/Examples_of_completed_tasks_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import csv
  
x = []
y = []
  
with open('Dengue_Daily_EN.csv','r') as csvfile:
    lines = csv.reader(csvfile, delimiter=',')
    for row in lines:
        x.append(row[1])
        y.append(row[2])
denv2 = df[df['Serotype'] == 'DENV2'] 
denv2
# Out:
#        Date_Onset Date_Confirmation Date_Notification Sex Age_Group  \
# 1      1998/01/03              None        1998/01/14   M     30-34
# 10     1998/02/17              None        1998/02/23   F     30-34
# 40     1998/07/11              None        1998/07/22   M     15-19
# 42     1998/07/15              None        1998/07/16   F     60-64
# 49     1998/07/30              None        1998/08/04   M     50-54
# ...           ...               ...               ...  ..       ...
# 79239  2019/02/13        2019/02/20        2019/02/17   M     40-44
# 79240  2019/02/13        2019/02/14        2019/02/13   M     20-24
# 79241  2019/02/14        2019/02/18        2019/02/15   M     30-34
# 79246  2019/02/16        2019/02/19        2019/02/18   F     20-24
# 79256  2019/02/27        2019/03/02        2019/02/28   M     25-29
#
#          County_living    Township_living Village_Living Village_Living_Code  \
# ...

# %%
plt.plot(x, y, color = 'r', linestyle = 'dashed',
         marker = 'o',label = "Dengue Daily Report")
  
plt.xticks(rotation = 25)
plt.xlabel('Date_Confirmation')
plt.ylabel('Age_Group')
plt.title('Dengue Daily Report', fontsize = 20)
plt.grid()
plt.legend()
plt.show()
